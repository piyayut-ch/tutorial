# %%
library(tidyverse)
library(extrafont)

# font_import()
loadfonts(device = "win", quiet = TRUE)
# Out:
# Registering fonts with R

# %%
ggplot(mtcars, aes(x = wt, y = mpg)) +
  geom_point() + 
  labs(x = "น้ำหนัก", y = "ไมล์ต่อแกลลอน", title = "ประสิทธิภาพรถยนต์") +
  theme(text = element_text(size = 16, family = "Athiti"))
# Out:
# plot without title
